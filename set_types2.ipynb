# %% [markdown]
# ## Settypes

# %% [markdown]
# ### 2. Frozenset

# %% [markdown]
# ### -Creation and immutability

# %%
platforms = frozenset(["Azure", "Python", "Databricks"])

# %%
# 1. Create a frozenset from a list
platforms = frozenset(["Azure", "Python", "Databricks", "Azure"]) # Duplicate ignored
print(f"Platforms frozenset: {platforms}")
# Out:
# Platforms frozenset: frozenset({'Python', 'Databricks', 'Azure'})

# %%
# 2. Create a frozenset from a tuple
core_skills = frozenset(("SQL", "Python"))
print(f"Core skills frozenset: {core_skills}")
# Out:
# Core skills frozenset: frozenset({'Python', 'SQL'})

# %%
# 3. Create from a string (unique chars)
fs_chars = frozenset("Edukron")
print(f"Frozenset from 'Edukron': {fs_chars}")
# Out:
# Frozenset from 'Edukron': frozenset({'E', 'o', 'd', 'r', 'n', 'u', 'k'})

# %%
# 3. Create from a string (unique chars)
fs_chars = frozenset("Python")
print(f"3. Frozenset from 'Python': {fs_chars}")
# Out:
# 3. Frozenset from 'Python': frozenset({'P', 'y', 'o', 't', 'n', 'h'})

# %%
# 3. Create from a string (unique chars)
fs_chars = frozenset("Python","Edukron") # This will raise an error because frozenset() takes only one iterable argument
print(f"3. Frozenset from 'Python'&'Edukron': {fs_chars}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 3. Create from a string (unique chars)
# ----> 2 fs_chars = frozenset("Python","Edukron") # This will raise an error because frozenset() takes only one iterable argument
#       3 print(f"3. Frozenset from 'Python'&'Edukron': {fs_chars}")
#
# TypeError: frozenset expected at most 1 argument, got 2

# %%
# 4. Create an empty frozenset
empty_fs = frozenset()
print(f"Empty frozenset: {empty_fs}")
# Out:
# Empty frozenset: frozenset()

# %%
# 5. Attempt to add an element (AttributeError)
try:
    platforms.add("AWS")
except AttributeError as e:
    print(f"Error adding to frozenset: {e}")
# Out:
# Error adding to frozenset: 'frozenset' object has no attribute 'add'

# %%
# 6. Attempt to remove an element (AttributeError)
try:
    platforms.remove("Azure")
except AttributeError as e:
    print(f"Error removing from frozenset: {e}")
# Out:
# Error removing from frozenset: 'frozenset' object has no attribute 'remove'

# %%
# 7. Attempt to update (AttributeError)
try:
    platforms.update(["AWS"])
except AttributeError as e:
    print(f"Error updating frozenset: {e}")
# Out:
# Error updating frozenset: 'frozenset' object has no attribute 'update'

# %%
# 8. Create a set containing frozensets (possible because frozensets are hashable)
skill_combinations = {core_skills, frozenset(["ML", "Python"]), frozenset(["SQL"])}
print(f"Set of frozensets: {skill_combinations}")
# Out:
# Set of frozensets: {frozenset({'SQL'}), frozenset({'Python', 'SQL'}), frozenset({'Python', 'ML'})}

# %%
course_tools = {
    frozenset(["Python", "Pandas"]): "Data Analysis basics",
    platforms: "Cloud Data Engineering platform"
}
print(f"Dict with frozenset keys: {course_tools}")
print(f"Value for platforms key: {course_tools[platforms]}")
# Out:
# Dict with frozenset keys: {frozenset({'Python', 'Pandas'}): 'Data Analysis basics', frozenset({'Python', 'Databricks', 'Azure'}): 'Cloud Data Engineering platform'}
# Value for platforms key: Cloud Data Engineering platform

# %%
# 9. Use frozenset as dictionary key
course_tools = {
    frozenset(["Python", "Pandas"]): "Data Analysis basics",
    platforms: "Cloud Data Engineering platform"
}
print(f"Dict with frozenset keys: {course_tools}")
# Out:
# Dict with frozenset keys: {frozenset({'Python', 'Pandas'}): 'Data Analysis basics', frozenset({'Python', 'Databricks', 'Azure'}): 'Cloud Data Engineering platform'}

# %%
course_tools = {
    frozenset(["Python", "Pandas"]): "Data Analysis basics",
    platforms: "Cloud Data Engineering platform"
}
print(f"Value for platforms key: {course_tools[platforms]}")
# Out:
# Value for platforms key: Cloud Data Engineering platform

# %%
# 10. Frozenset from range
fs_range = frozenset(range(3)) # 0, 1, 2
print(f"Frozenset from range(3): {fs_range}")
# Out:
# Frozenset from range(3): frozenset({0, 1, 2})

# %% [markdown]
# ### - set operations with frozensets

# %%
platforms = frozenset(["Azure", "Python", "Databricks"])
cloud_tools = frozenset(["Azure", "AWS", "GCP"])
scripting = {"Python", "Bash"} # A regular set

# %%
# 1. Union of two frozensets (returns frozenset)
all_platforms = platforms.union(cloud_tools)
# or: all_platforms = platforms | cloud_tools
print(f"Union (fs | fs): {all_platforms}, Type: {type(all_platforms)}")
# Out:
# Union (fs | fs): frozenset({'Python', 'GCP', 'Databricks', 'AWS', 'Azure'}), Type: <class 'frozenset'>

# %%
# 2. Intersection of two frozensets (returns frozenset)
common_platforms = platforms.intersection(cloud_tools)
# or: common_platforms = platforms & cloud_tools
print(f"Intersection (fs & fs): {common_platforms}, Type: {type(common_platforms)}")
# Out:
# Intersection (fs & fs): frozenset({'Azure'}), Type: <class 'frozenset'>

# %%
# 3. Difference between two frozensets (returns frozenset)
platforms_only = platforms.difference(cloud_tools)
# or: platforms_only = platforms - cloud_tools
print(f"Difference (platforms - cloud_tools): {platforms_only}, Type: {type(platforms_only)}")
# Out:
# Difference (platforms - cloud_tools): frozenset({'Python', 'Databricks'}), Type: <class 'frozenset'>

# %%
# 3. Difference between two frozensets (returns frozenset)
platforms_only = platforms.difference(cloud_tools)
print(platforms)
print(cloud_tools)
# or: platforms_only = platforms - cloud_tools
print(f"Difference (platforms - cloud_tools): {platforms_only}, Type: {type(platforms_only)}")
# Out:
# frozenset({'Python', 'Databricks', 'Azure'})
# frozenset({'GCP', 'AWS', 'Azure'})
# Difference (platforms - cloud_tools): frozenset({'Python', 'Databricks'}), Type: <class 'frozenset'>

# %%
# 4. Symmetric difference between two frozensets (returns frozenset)
non_common_platforms = platforms.symmetric_difference(cloud_tools)
# or: non_common_platforms = platforms ^ cloud_tools
print(f"Symmetric Difference (fs ^ fs): {non_common_platforms}, Type: {type(non_common_platforms)}")
# Out:
# Symmetric Difference (fs ^ fs): frozenset({'GCP', 'Python', 'Databricks', 'AWS'}), Type: <class 'frozenset'>

# %%
# 4. Symmetric difference between two frozensets (returns frozenset)
non_common_platforms = platforms.symmetric_difference(cloud_tools)
print(platforms)
print(cloud_tools)
# or: non_common_platforms = platforms ^ cloud_tools
print(f"Symmetric Difference (fs ^ fs): {non_common_platforms}, Type: {type(non_common_platforms)}")
# Out:
# frozenset({'Python', 'Databricks', 'Azure'})
# frozenset({'GCP', 'AWS', 'Azure'})
# Symmetric Difference (fs ^ fs): frozenset({'GCP', 'Python', 'Databricks', 'AWS'}), Type: <class 'frozenset'>

# %%
# 5. Union of frozenset and set (returns set)
platform_scripting = platforms.union(scripting)
# or: platform_scripting = platforms | scripting
print(f"Union (fs | set): {platform_scripting}, Type: {type(platform_scripting)}")
# Out:
# Union (fs | set): frozenset({'Python', 'Bash', 'Databricks', 'Azure'}), Type: <class 'frozenset'>

# %%
# 6. Intersection of frozenset and set (returns set)
common_platform_scripting = platforms.intersection(scripting)
# or: common_platform_scripting = platforms & scripting
print(f"Intersection (fs & set): {common_platform_scripting}, Type: {type(common_platform_scripting)}")
# Out:
# Intersection (fs & set): frozenset({'Python'}), Type: <class 'frozenset'>

# %%
# 7. Difference (frozenset - set) (returns set)
platforms_not_scripting = platforms.difference(scripting)
# or: platforms_not_scripting = platforms - scripting
print(f"Difference (fs - set): {platforms_not_scripting}, Type: {type(platforms_not_scripting)}")
# Out:
# Difference (fs - set): frozenset({'Databricks', 'Azure'}), Type: <class 'frozenset'>

# %%
# 8. Symmetric Difference (frozenset ^ set) (returns set)
non_common_platform_scripting = platforms.symmetric_difference(scripting)
# or: non_common_platform_scripting = platforms ^ scripting
print(f"Symmetric Difference (fs ^ set): {non_common_platform_scripting}, Type: {type(non_common_platform_scripting)}")
# Out:
# Symmetric Difference (fs ^ set): frozenset({'Bash', 'Databricks', 'Azure'}), Type: <class 'frozenset'>

# %%
# 9. Checking subset relationship
is_subset = frozenset(["Python", "Azure"]).issubset(platforms)
print(f"Is {{'Python', 'Azure'}} subset of platforms? {is_subset}")
# Out:
# Is {'Python', 'Azure'} subset of platforms? True

# %%
# 10. Checking superset relationship
is_superset = platforms.issuperset({"Python"})
print(f"Is platforms superset of {{'Python'}}? {is_superset}")
# Out:
# Is platforms superset of {'Python'}? True
