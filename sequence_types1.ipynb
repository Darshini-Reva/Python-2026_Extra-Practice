# %% [markdown]
# ## list

# %% [markdown]
# ### Creation and Indexing/Slicing

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Python Basics", "SQL Fundamentals"]
student_counts = [350, 420, 380, 500, 450]

# %%
# 1. Create a list of courses
print(f"Course List: {course_list}")
# Out:
# Course List: ['Data Science', 'Data Engineering', 'Azure DevOps', 'Python Basics', 'SQL Fundamentals']

# %%
# 2. Access the first course
first_course = course_list[0]
print(f"First course: {first_course}")
# Out:
# First course: Data Science

# %%
# 3. Access the last course count
last_count = student_counts[-1]
print(f"Last course count: {last_count}")
# Out:
# Last course count: 450

# %%
# 4. Get a slice of the first three courses
first_three_courses = course_list[0:3] # or [:3]
print(f"First three courses: {first_three_courses}")
# Out:
# First three courses: ['Data Science', 'Data Engineering', 'Azure DevOps']

# %%
# 5. Get a slice of student counts from index 1 to 3 (exclusive)
counts_slice = student_counts[1:3]
print(f"Student counts slice [1:3]: {counts_slice}")
# Out:
# Student counts slice [1:3]: [420, 380]

# %%
# 6. Get every second course starting from the first
every_second_course = course_list[::2]
print(f"Every second course: {every_second_course}")
# Out:
# Every second course: ['Data Science', 'Azure DevOps', 'SQL Fundamentals']

# %%
# 7. Create a list with mixed data types
batch_info = ["DE101", "Data Engineering", 45, True] # ID, Name, Size, Active
print(f"Mixed type list: {batch_info}")
# Out:
# Mixed type list: ['DE101', 'Data Engineering', 45, True]

# %%
# 8. Access an element in the mixed list
batch_info = ["DE101", "Data Engineering", 45, True]
batch_size = batch_info[2]
print(f"Accessing batch size: {batch_size}")
# Out:
# Accessing batch size: 45

# %%
# 9. Get the last two items using slicing
last_two_items = batch_info[-2:]
print(f"Last two items: {last_two_items}")
# Out:
# Last two items: [45, True]

# %%
# 10. Create an empty list
upcoming_courses = []
print(f"Empty list: {upcoming_courses}")
# Out:
# Empty list: []

# %% [markdown]
# ### list.append(item)

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
new_enrollments = [15, 20, 10]

# %%
# 1. Add a new course to the list
course_list.append("Cloud Computing")
print(f"List after appending course: {course_list}")
# Out:
# List after appending course: ['Data Science', 'Data Engineering', 'Azure DevOps', 'Cloud Computing']

# %%
# 2. Add another course
course_list.append("Machine Learning")
print(f"List after appending another: {course_list}")
# Out:
# List after appending another: ['Data Science', 'Data Engineering', 'Azure DevOps', 'Cloud Computing', 'Machine Learning']

# %%
# 3. Append a number to a list of numbers
new_enrollments.append(18)
print(f"Enrollments after append: {new_enrollments}")
# Out:
# Enrollments after append: [15, 20, 10, 18]

# %%
# 4. Append a list as a single item (nested list)
meta_list = [1, 2]
meta_list.append([3, 4])
print(f"List after appending a list: {meta_list}")
# Out:
# List after appending a list: [1, 2, [3, 4]]

# %%
# 5. Append a student name to a batch list
batch_students = ["Alice", "Bob"]
batch_students.append("Charlie")
print(f"Batch students after append: {batch_students}")
# Out:
# Batch students after append: ['Alice', 'Bob', 'Charlie']

# %%
# 6. Start with an empty list and append items
feedback_scores = []
feedback_scores.append(5)
feedback_scores.append(4)
feedback_scores.append(5)
print(f"Feedback scores built with append: {feedback_scores}")
# Out:
# Feedback scores built with append: [5, 4, 5]

# %%
# 7. Append a boolean value
flags = [True, False]
flags.append(True)
print(f"Flags after append: {flags}")
# Out:
# Flags after append: [True, False, True]

# %%
# 8. Append None
optional_features = ["Feature A"]
optional_features.append(None) # Representing an unconfigured feature
print(f"Features after appending None: {optional_features}")
# Out:
# Features after appending None: ['Feature A', None]

# %%
# 8. Append 0
optional_features = ["Feature A"]
optional_features.append(0) # Representing an unconfigured feature
print(f"Features after appending None: {optional_features}")
# Out:
# Features after appending None: ['Feature A', 0]

# %%
# 9. Append result of a calculation
values = [10, 20]
values.append(values[0] + values[1]) # Append 30
print(f"Values after appending sum: {values}")
# Out:
# Values after appending sum: [10, 20, 30]

# %%
# 10. Append a tuple as a single item
coordinates = [(0,0), (1,1)]
coordinates.append((2, 3))
print(f"Coordinates after appending tuple: {coordinates}")
# Out:
# Coordinates after appending tuple: [(0, 0), (1, 1), (2, 3)]

# %% [markdown]
# ### list.extend(iterable)

# %%
data_science_courses = ["DS Intro", "Python for DS"]
data_eng_courses = ["DE Intro", "SQL for DE", "ADF"]
new_tools = ("Docker", "Kubernetes")

# %%
# 1. Extend DS courses with DE courses
data_science_courses.extend(data_eng_courses)
print(f"Extended DS courses: {data_science_courses}")
# Out:
# Extended DS courses: ['DS Intro', 'Python for DS', 'DE Intro', 'SQL for DE', 'ADF']

# %%
# 1. Extend DS courses with DE courses
data_science_courses1 = data_science_courses + data_eng_courses  ## (+) operator will not work as extend
print(f"Extended DS courses: {data_science_courses1}")
# Out:
# Extended DS courses: ['DS Intro', 'Python for DS', 'DE Intro', 'SQL for DE', 'ADF', 'DE Intro', 'SQL for DE', 'ADF']

# %%
# 2. Extend with a tuple of new tools
all_tools = ["Python", "SQL"]
all_tools.extend(new_tools)
print(f"All tools after extend: {all_tools}")
# Out:
# All tools after extend: ['Python', 'SQL', 'Docker', 'Kubernetes']

# %%
# 3. Extend with another list
batch_1_students = ["Alice", "Bob"]
batch_2_students = ["Charlie", "David"]
batch_1_students.extend(batch_2_students)
print(f"Combined batch 1 students: {batch_1_students}")
# Out:
# Combined batch 1 students: ['Alice', 'Bob', 'Charlie', 'David']

# %%
# 4. Extend with a string (adds each character)
letters = ['a', 'b']
letters.extend("cde")
print(f"Letters extended with string: {letters}")
# Out:
# Letters extended with string: ['a', 'b', 'c', 'd', 'e']

# %%
# 5. Extend an empty list
empty_list = []
empty_list.extend([1, 2, 3])
print(f"Extending an empty list: {empty_list}")
# Out:
# Extending an empty list: [1, 2, 3]

# %%
# 6. Extend with items from a set (order not guaranteed from set)
topics = ["Visualization"]
data_analytics_topics = {"Power BI", "EDA", "Reporting"} # Set
topics.extend(data_analytics_topics)
print(f"Topics extended with set items: {topics}")
# Out:
# Topics extended with set items: ['Visualization', 'Reporting', 'EDA', 'Power BI']

# %%
# 7. Extend with a list created on the fly
numbers = [10, 20]
numbers.extend([30, 40])
print(f"Numbers extended with list literal: {numbers}")
# Out:
# Numbers extended with list literal: [10, 20, 30, 40]

# %%
# 7. Extend with a list created on the fly
numbers = (10, 20)
numbers.extend(30, 40)
print(f"Numbers extended with list literal: {numbers}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 3
#       1 # 7. Extend with a list created on the fly
#       2 numbers = (10, 20)
# ----> 3 numbers.extend(30, 40)
#       4 print(f"Numbers extended with list literal: {numbers}")
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
# 8. Extend using range (converted implicitly)
ids = [101, 102]
ids.extend(range(103, 105)) # Adds 103, 104
print(f"IDs extended with range: {ids}")
# Out:
# IDs extended with range: [101, 102, 103, 104]

# %%
# 9. Extend a list with itself (doubles the list)
items = ["Module 1", "Module 2"]
items.extend(items)
print(f"Items extended with itself: {items}")
# Out:
# Items extended with itself: ['Module 1', 'Module 2', 'Module 1', 'Module 2']

# %%
# 10. Contrast with append: extending vs appending a list
list_a = [1, 2]
list_b = [3, 4]
list_a.extend(list_b) 
print(f"After extend: {list_a}")
print()
list_c = [1, 2]
list_c.append(list_b) 
print(f"After append: {list_c}")
# Out:
# After extend: [1, 2, 3, 4]
#
# After append: [1, 2, [3, 4]]

# %% [markdown]
# ### list.insert(index,item)

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
priority_tasks = ["Deploy App", "Monitor Logs"]

# %%
# 1. Insert "Python Basics" at the beginning (index 0)
course_list.insert(0, "Python Basics")
print(f"List after inserting at index 0: {course_list}")
# Out:
# List after inserting at index 0: ['Python Basics', 'Data Science', 'Data Engineering', 'Azure DevOps']

# %%
# 2. Insert "Cloud Intro" at index 2
course_list.insert(2, "Cloud Intro")
print(f"List after inserting at index 2: {course_list}")
# Out:
# List after inserting at index 2: ['Python Basics', 'Data Science', 'Cloud Intro', 'Data Engineering', 'Azure DevOps']

# %%
# 3. Insert a high-priority task at the beginning
priority_tasks.insert(0, "Fix Critical Bug")
print(f"Priority tasks after insert: {priority_tasks}")
# Out:
# Priority tasks after insert: ['Fix Critical Bug', 'Deploy App', 'Monitor Logs']

# %%
# 4. Insert using a negative index (-1 inserts before the last item)
numbers = [1, 2, 3, 5]
numbers.insert(-1, 4) # Insert 4 before the last item (5)
print(f"Numbers after inserting at -1: {numbers}")
# Out:
# Numbers after inserting at -1: [1, 2, 3, 4, 5]

# %%
# 5. Insert at an index equal to the length (equivalent to append)
tasks = ["Task A", "Task B"]
tasks.insert(len(tasks), "Task C")
print(f"Inserting at len(list): {tasks}")
# Out:
# Inserting at len(list): ['Task A', 'Task B', 'Task C']

# %%
# 6. Insert at an index larger than the length (inserts at the end)
modules = ["M1", "M2"]
modules.insert(100, "M3") # Index 100 is beyond length, inserts at end
print(f"Inserting at index > len: {modules}")
# Out:
# Inserting at index > len: ['M1', 'M2', 'M3']

# %%
# 7. Insert at a negative index far beyond the beginning (inserts at beginning)
flags = [True, False]
flags.insert(-100, None) # Index -100 is before beginning, inserts at 0
print(f"Inserting at index < -len: {flags}")
# Out:
# Inserting at index < -len: [None, True, False]

# %%
# 8. Insert a list as an item
nested = [1, [3, 4]]
nested.insert(1, 2)
print(f"Inserting into a list with nested list: {nested}")
# Out:
# Inserting into a list with nested list: [1, 2, [3, 4]]

# %%
# 9. Insert into an empty list (only index 0 is valid without append behavior)
empty = []
empty.insert(0, "First Item")
print(f"Inserting into empty list: {empty}")
# Out:
# Inserting into empty list: ['First Item']

# %%
# 10. Insert duplicate item
ratings = [4, 5, 5]
ratings.insert(1, 5)
print(f"Inserting a duplicate item: {ratings}")
# Out:
# Inserting a duplicate item: [4, 5, 5, 5]

# %% [markdown]
# ### list.remove(item)

# %%
course_list = ["Python Basics", "Data Science", "Cloud Intro", "Data Engineering", "Data Science"]
tools = ["Python", "SQL", "Git", "SQL"]

# %%
# 1. Remove "Cloud Intro"
course_list.remove("Cloud Intro")
print(f"List after removing 'Cloud Intro': {course_list}")
# Out:
# List after removing 'Cloud Intro': ['Python Basics', 'Data Science', 'Data Engineering', 'Data Science']

# %%
# 2. Remove the first occurrence of "Data Science"
course_list.remove("Data Science")
print(f"List after removing first 'Data Science': {course_list}")
# Out:
# List after removing first 'Data Science': ['Python Basics', 'Data Engineering', 'Data Science']

# %%
# 3. Remove the first occurrence of "SQL"
tools.remove("SQL")
print(f"Tools after removing first 'SQL': {tools}")
# Out:
# Tools after removing first 'SQL': ['Python', 'Git', 'SQL']

# %%
# 4. Remove "Git"
tools.remove("Git")
print(f"Tools after removing 'Git': {tools}")
# Out:
# Tools after removing 'Git': ['Python', 'SQL']

# %%
# 5. Attempt to remove an item not in the list
try:
    tools.remove("Java")
except ValueError as e:
    print(f"Error removing 'Java': {e}")
# Out:
# Error removing 'Java': list.remove(x): x not in list

# %%
# 6. Remove an integer item
student_counts = [350, 420, 380, 420]
student_counts.remove(420) # Removes the first 420
print(f"Counts after removing first 420: {student_counts}")
# Out:
# Counts after removing first 420: [350, 380, 420]

# %%
# 7. Remove a boolean item
flags = [True, False, True]
flags.remove(True) # Removes the first True
print(f"Flags after removing first True: {flags}")
# Out:
# Flags after removing first True: [False, True]

# %%
# 8. Remove None
items = ["A", None, "B", None]
items.remove(None) # Removes the first None
print(f"Items after removing first None: {items}")
# Out:
# Items after removing first None: ['A', 'B', None]

# %%
# 9. Removing from a list with one item
single_item_list = ["Final Project"]
single_item_list.remove("Final Project")
print(f"Removing the only item: {single_item_list}")
# Out:
# Removing the only item: []

# %%
# 10. Remove item based on a variable
course_to_remove = "Data Engineering"
if course_to_remove in course_list:
    course_list.remove(course_to_remove)
print(f"List after removing '{course_to_remove}': {course_list}")
# Out:
# List after removing 'Data Engineering': ['Python Basics', 'Data Science']
