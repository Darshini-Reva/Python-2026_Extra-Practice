# %% [markdown]
# ## text type (str)

# %% [markdown]
# ### Concatenation (+) and Repetition(*)

# %%
institute = "Edukron"
focus_area = "Data Science"

# %%
# 1. Combining institute and focus area
full_title = institute + ": " + focus_area
print(f"Full title: {full_title}")
# Out:
# Full title: Edukron: Data Science

# %%
# 2. Creating a course welcome message
course_name = "Azure DevOps"
welcome_message = "Welcome to " + institute + "'s " + course_name + " course!"
print(f"Welcome message: {welcome_message}")
# Out:
# Welcome message: Welcome to Edukron's Azure DevOps course!

# %%
# 3. Repeating a separator
separator = "-*=" * 10
print(f"Separator: {separator}")
# Out:
# Separator: -*=-*=-*=-*=-*=-*=-*=-*=-*=-*=

# %%
# 4. Emphasizing a keyword
keyword = " Python "
emphasized = keyword * 4
print(f"Emphasized keyword: {emphasized}")
# Out:
# Emphasized keyword:  Python  Python  Python  Python

# %%
# 5. Building a file path (simple example, os.path.join is better)
base_path = "/courses/"
course_id = "DA101"
full_path = base_path + course_id
print(f"Simple path: {full_path}")
# Out:
# Simple path: /courses/DA101

# %%
# 6. Adding a suffix
student_name = "Alex"
username_suffix = "@edukron.com"
email = student_name + username_suffix
print(f"Student email: {email}")
# Out:
# Student email: Alex@edukron.com

# %%
# 7. Repeating a character for underlining (approximate length)
heading = "Course Modules"
underline = "=" * len(heading) # len() gives length
print(f"Heading:\n{heading}\n{underline}")
# Out:
# Heading:
# Course Modules
# ==============

# %%
# 8. Concatenating multiple strings
part1 = "Learn "
part2 = "Data Engineering "
part3 = "Now!"
call_to_action = part1 + part2 + part3
print(f"Call to action: {call_to_action}")
# Out:
# Call to action: Learn Data Engineering Now!

# %%
# 9. Repeating an empty string (results in empty string)
empty_repeated = "" * 100
print(f"Repeating empty string: '{empty_repeated}'")
# Out:
# Repeating empty string: ''

# %%
# 10. Repeating a string zero times (results in empty string)
message = "ALERT! "
no_alerts = message * 0
print(f"Repeating zero times: '{no_alerts}'")
# Out:
# Repeating zero times: ''

# %%
# 10. Repeating a string one times 
message = "ALERT! "
no_alerts = message * 1
print(f"Repeating zero times: '{no_alerts}'")
# Out:
# Repeating zero times: 'ALERT! '

# %% [markdown]
# ### len()

# %%
institute = "Edukron"
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python"

# %%
# 1. Length of the institute name
name_length = len(institute)
print(f"Length of '{institute}': {name_length}")
# Out:
# Length of 'Edukron': 7

# %%
# 2. Length of the course slogan
slogan_length = len(course_slogan)
print(f"Length of slogan: {slogan_length}")
# Out:
# Length of slogan: 46

# %%
# 3. Length of the tech stack description
stack_length = len(tech_stack)
print(f"Length of tech stack: {stack_length}")
# Out:
# Length of tech stack: 23

# %%
# 4. Length of an empty string
empty_len = len("")
print(f"Length of empty string: {empty_len}")
# Out:
# Length of empty string: 0

# %%
# 5. Length of a string with only spaces
spaces = "   "
spaces_len = len(spaces)
print(f"Length of '{spaces}': {spaces_len}")
# Out:
# Length of '   ': 3

# %%
# 6. Using len() for validation (e.g., minimum password length)
password = "pass"
min_len = 8
if len(password) < min_len:
    print(f"Password '{password}' is too short (min {min_len} chars).")
# Out:
# Password 'pass' is too short (min 8 chars).

# %%
# 6. Using len() for validation 
password = "pass123546"
min_len = 8
if len(password) > min_len:
    print(f"Password approved")
# Out:
# Password approved

# %%
# 7. Length of a string containing numbers and symbols
complex_str = "Batch #101!"
complex_len = len(complex_str)
print(f"Length of '{complex_str}': {complex_len}")
# Out:
# Length of 'Batch #101!': 11

# %%
# 8. Length after concatenation
combined = institute + tech_stack # "EdukronAzure DevOps and Python"
combined_len = len(combined)
print(f"Length of combined string: {combined_len}")
# Out:
# Length of combined string: 30

# %%
# 9. Length of a single character string
char_str = "A"
char_len = len(char_str)
print(f"Length of '{char_str}': {char_len}")
# Out:
# Length of 'A': 1

# %%
# 10. Length of a multi-line string (includes newline characters)
multi_line = """Line 1
Line 2"""
multi_len = len(multi_line)
print(f"Length of multi-line string:\n'''{multi_line}'''\nis: {multi_len}")
# Out:
# Length of multi-line string:
# '''Line 1
# Line 2'''
# is: 13

# %% [markdown]
# ### Indexing ([]) and slicing[:]

# %%
institute = "Edukron"
tech_stack = "Azure DevOps and Python"

# %%
# --- Indexing ---
# 1. Get the first character of institute
first_char = institute[0]
print(f"First character of '{institute}': {first_char}")
# Out:
# First character of 'Edukron': E

# %%
# 2. Get the last character of institute
last_char = institute[-1]
print(f"Last character of '{institute}': {last_char}")
# Out:
# Last character of 'Edukron': n

# %%
# 3. Get the character at index 3
char_at_3 = institute[3]
print(f"Character at index 3 of '{institute}': {char_at_3}")
# Out:
# Character at index 3 of 'Edukron': k

# %%
# --- Slicing ---
# 4. Get the first 5 characters of tech_stack ("Azure")
first_5 = tech_stack[0:5] # or [:5]
print(f"First 5 chars of tech_stack: '{first_5}'")
# Out:
# First 5 chars of tech_stack: 'Azure'

# %%
## 5. Get the substring "DevOps" (index 6 to 12, exclusive)
devops_part = tech_stack[6:12]
print(f"Extracting 'DevOps': '{devops_part}'")
# Out:
# Extracting 'DevOps': 'DevOps'

# %%
# 6. Get the last 6 characters ("Python")
last_6 = tech_stack[-6:]
print(f"Last 6 chars of tech_stack: '{last_6}'")
# Out:
# Last 6 chars of tech_stack: 'Python'

# %%
# 7. Get everything *except* the first and last character
middle = institute[1:-1]
print(f"Middle part of '{institute}': '{middle}'")
# Out:
# Middle part of 'Edukron': 'dukro'

# %%
# 8. Get every second character of institute
every_second = institute[::2]
print(f"Every second char of '{institute}': '{every_second}'")
# Out:
# Every second char of 'Edukron': 'Eurn'

# %%
# 9. Reverse the institute name using slicing
reversed_name = institute[::-1]
print(f"Reversed '{institute}': '{reversed_name}'")
# Out:
# Reversed 'Edukron': 'norkudE'

# %%
# 10. Get a slice from index 6 onwards
from_index_6 = tech_stack[6:]
print(f"Tech stack from index 6: '{from_index_6}'")
# Out:
# Tech stack from index 6: 'DevOps and Python'

# %% [markdown]
# ### str.lower() and str.upper()

# %%
institute = "Edukron"
focus_area = "Data Science"
tech_stack = "Azure DevOps and Python"

# %%
# 1. Institute name in lowercase
lower_institute = institute.lower()
print(f"Lowercase institute: '{lower_institute}'")
# Out:
# Lowercase institute: 'edukron'

# %%
# 2. Focus area in uppercase
upper_focus = focus_area.upper()
print(f"Uppercase focus area: '{upper_focus}'")
# Out:
# Uppercase focus area: 'DATA SCIENCE'

# %%
# 3. Tech stack in lowercase
lower_stack = tech_stack.lower()
print(f"Lowercase tech stack: '{lower_stack}'")
# Out:
# Lowercase tech stack: 'azure devops and python'

# %%
# 4. Case-insensitive comparison
user_input = "data science"
if user_input.lower() == focus_area.lower():
    print("User input matches focus area (case-insensitive).")
# Out:
# User input matches focus area (case-insensitive).

# %%
# 5. Converting mixed case to uppercase
mixed_case = "PyThOn PrOjEcT"
upper_mixed = mixed_case.upper()
print(f" Uppercase mixed case: '{upper_mixed}'")
# Out:
#  Uppercase mixed case: 'PYTHON PROJECT'

# %%
# 6. Converting mixed case to lowercase
mixed_case = "PyThOn PrOjEcT"
lower_mixed = mixed_case.lower()
print(f"Lowercase mixed case: '{lower_mixed}'")
# Out:
# Lowercase mixed case: 'python project'

# %%
# 7. Applying to a string with numbers/symbols (they remain unchanged)
code = "Batch-101-DS"
lower_code = code.lower()
upper_code = code.upper()
print(f"Lowercase code: '{lower_code}', Uppercase code: '{upper_code}'")
# Out:
# Lowercase code: 'batch-101-ds', Uppercase code: 'BATCH-101-DS'

# %%
# 8. Chaining after concatenation
full_title = institute + ": " + focus_area
upper_title = full_title.upper()
print(f"Uppercase full title: '{upper_title}'")
# Out:
# Uppercase full title: 'EDUKRON: DATA SCIENCE'

# %%
# 9. Applying to an already lowercase string
already_lower = "real-time"
result = already_lower.lower()
print(f"Applying lower() to lowercase string: '{result}'")
# Out:
# Applying lower() to lowercase string: 'real-time'

# %%
# 10. Applying to an already uppercase string
already_upper = "AZURE"
result = already_upper.upper()
print(f"Applying upper() to uppercase string: '{result}'")
# Out:
# Applying upper() to uppercase string: 'AZURE'

# %% [markdown]
# ### str.strip() , str.lstrip(), str.rstrip()

# %%
# 1. Removing leading/trailing whitespace
user_input = "  Data Science  "
cleaned_input = user_input.strip()
print(f"Stripped input: '{cleaned_input}'")
# Out:
# Stripped input: 'Data Science'

# %%
# 2. Removing only leading whitespace
leading_space = "   Edukron"
left_stripped = leading_space.lstrip()
print(f"Left-stripped: '{left_stripped}'")
# Out:
# Left-stripped: 'Edukron'

# %%
# 3. Removing only trailing whitespace
trailing_space = "Python   "
right_stripped = trailing_space.rstrip()
print(f"Right-stripped: '{right_stripped}'")
# Out:
# Right-stripped: 'Python'

# %%
# 4. Stripping specific characters (e.g., punctuation)
course_code = "===DS101==="
cleaned_code = course_code.strip("=")
print(f"Stripped specific chars: '{cleaned_code}'")
# Out:
# Stripped specific chars: 'DS101'

# %%
# 4. Stripping specific characters (e.g., punctuation)
course_code = "===DS101==="
cleaned_code = course_code.lstrip("=")
print(f"Stripped specific chars: '{cleaned_code}'")
# Out:
# Stripped specific chars: 'DS101==='

# %%
# 5. Stripping multiple different characters from ends
path = "/courses/Azure/"
cleaned_path = path.strip("/e") # Removes '/' and 'e' from ends
print(f"Stripping multiple chars: '{cleaned_path}'")
# Out:
# Stripping multiple chars: 'courses/Azur'

# %%
# 6. Using lstrip with specific characters
filename = "__init__.py"
stripped_filename = filename.lstrip("_")
print(f"Left-stripped specific chars: '{stripped_filename}'")
# Out:
# Left-stripped specific chars: 'init__.py'

# %%
# 7. Using rstrip with specific characters
version = "v1.0.RELEASE..."
stripped_version = version.rstrip(".RELEASE") # Removes '.', 'R', 'E', 'L', 'A', 'S' from end
print(f"Right-stripped specific chars: '{stripped_version}'")
# Out:
# Right-stripped specific chars: 'v1.0'

# %%
# 8. Stripping whitespace from a multi-line string's ends
multi_line = "\n  Line 1 \n Line 2 \t\n"
stripped_multi = multi_line.strip()
print(f"Stripped multi-line:\n'''{stripped_multi}'''")
# Out:
# Stripped multi-line:
# '''Line 1
#  Line 2'''

# %%
# 9. No characters to strip
clean_string = "Edukron"
result = clean_string.strip()
print(f"Stripping a clean string: '{result}'")
# Out:
# Stripping a clean string: 'Edukron'

# %%
# 10. Stripping only characters specified
special_format = "***Python***"     # Only strips '*' not whitespace if specified
result = special_format.strip('*')
print(f"Stripping only '*': '{result}'")
# Out:
# Stripping only '*': 'Python'
