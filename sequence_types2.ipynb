# %% [markdown]
# ## list[]

# %% [markdown]
# ### list.pop([index])

# %%
course_list = ["Python Basics", "Data Science", "Data Engineering"]
tasks = ["Review Code", "Update Docs", "Deploy"]

# %%
# 1. Pop the last item (default index -1)
last_course = course_list.pop()
print(f"Popped last course: '{last_course}', List is now: {course_list}")
# Out:
# Popped last course: 'Data Engineering', List is now: ['Python Basics', 'Data Science']

# %%
# 2. Pop the item at index 0
first_course = course_list.pop(0)
print(f"Popped first course: '{first_course}', List is now: {course_list}")
# Out:
# Popped first course: 'Python Basics', List is now: ['Data Science']

# %%
# 3. Pop the last task
last_task = tasks.pop()
print(f"Popped last task: '{last_task}', Tasks left: {tasks}")
# Out:
# Popped last task: 'Deploy', Tasks left: ['Review Code', 'Update Docs']

# %%
# 4. Pop the item at index 1
middle_task = tasks.pop(1)
print(f"Popped task at index 1: '{middle_task}', Tasks left: {tasks}")
# Out:
# Popped task at index 1: 'Update Docs', Tasks left: ['Review Code']

# %%
# 5. Pop the only remaining item
only_task = tasks.pop()
print(f"Popped only task: '{only_task}', Tasks left: {tasks}")
# Out:
# Popped only task: 'Review Code', Tasks left: []

# %%
# 6. Attempt to pop from an empty list (causes IndexError)
try:
    tasks.pop()
except IndexError as e:
    print(f"Error popping from empty list: {e}")
# Out:
# Error popping from empty list: pop from empty list

# %%
# 7. Pop using a negative index (-1 is last, -2 is second last)
numbers = [10, 20, 30, 40]
second_last = numbers.pop(-2)
print(f"Popped second last number: {second_last}, List is now: {numbers}")
# Out:
# Popped second last number: 30, List is now: [10, 20, 40]

# %%
# 8. Pop the new last number
new_last = numbers.pop()
print(f"Popped new last number: {new_last}, List is now: {numbers}")
# Out:
# Popped new last number: 40, List is now: [10, 20]

# %%
# 9. Pop first element again
first_again = numbers.pop(0)
print(f"Popped first element again: {first_again}, List is now: {numbers}")
# Out:
# Popped first element again: 10, List is now: [20]

# %%
# 10. Attempt to pop with index out of range
try:
    numbers.pop(5) # Only index 0 is valid now
except IndexError as e:
    print(f"Error popping index 5: {e}")
# Out:
# Error popping index 5: pop index out of range

# %% [markdown]
# ### list.sort(key=None, reverse=False)

# %%
course_list = ["Data Engineering", "Azure DevOps", "Data Science", "Python Basics"]
student_counts = [350, 420, 380, 500, 450]
mixed_case_courses = ["azure DevOps", "Python basics", "Data science"]

# %%
# 1. Sort course list alphabetically (in-place)
course_list.sort()
print(f"Sorted courses: {course_list}")
# Out:
# Sorted courses: ['Azure DevOps', 'Data Engineering', 'Data Science', 'Python Basics']

# %%
# 2. Sort student counts numerically (ascending)
student_counts.sort()
print(f"Sorted counts: {student_counts}")
# Out:
# Sorted counts: [350, 380, 420, 450, 500]

# %%
# 3. Sort student counts in descending order
student_counts.sort(reverse=True)
print(f"Counts sorted descending: {student_counts}")
# Out:
# Counts sorted descending: [500, 450, 420, 380, 350]

# %%
# 4. Sort mixed case courses case-insensitively
mixed_case_courses.sort(key=str.lower)
print(f"Mixed case sorted case-insensitively: {mixed_case_courses}")
# Out:
# Mixed case sorted case-insensitively: ['azure DevOps', 'Data science', 'Python basics']

# %%
# 5. Sort list of tuples based on the second element (student count)
course_enrollments = [("Data Science", 380), ("Python Basics", 500), ("Azure DevOps", 420)]
course_enrollments.sort(key=lambda item: item[1]) # Sort by count (item[1])
print(f"Courses sorted by enrollment: {course_enrollments}")
# Out:
# Courses sorted by enrollment: [('Data Science', 380), ('Azure DevOps', 420), ('Python Basics', 500)]

# %%
# 5. Sort list of tuples 
course_enrollments = [("Data Science", 380), ("Python Basics", 500), ("Azure DevOps", 420)]
course_enrollments.sort(reverse=False) # Sort by count (item[1])
print(f"Courses sorted by enrollment: {course_enrollments}")
# Out:
# Courses sorted by enrollment: [('Azure DevOps', 420), ('Data Science', 380), ('Python Basics', 500)]

# %%
# 6. Sort descending by enrollment
course_enrollments.sort(key=lambda item: item[1], reverse=True)
print(f"Courses sorted descending by enrollment: {course_enrollments}")
# Out:
# Courses sorted descending by enrollment: [('Python Basics', 500), ('Azure DevOps', 420), ('Data Science', 380)]

# %%
# 7. Sort list based on length of strings
courses = ["SQL", "Python", "Azure DevOps", "Git"]
courses.sort(key=len)
print(f"Courses sorted by length: {courses}")
# Out:
# Courses sorted by length: ['SQL', 'Git', 'Python', 'Azure DevOps']

# %%
# 8. Sort list of lists based on the first element
batches = [[102, 'DE'], [101, 'DS'], [103, 'ADO']]
batches.sort() # Default sorts by first element, then second if first is equal
print(f"Batches sorted by ID: {batches}")
# Out:
# Batches sorted by ID: [[101, 'DS'], [102, 'DE'], [103, 'ADO']]

# %%
# 9. Sort a list that is already sorted
already_sorted = [10, 20, 30]
already_sorted.sort()
print(f"Sorting an already sorted list: {already_sorted}")
# Out:
# Sorting an already sorted list: [10, 20, 30]

# %%
# 10. Attempt to sort list with incompatible types (TypeError)
incompatible_list = ["Data Science", 420, True]
try:
    incompatible_list.sort()
except TypeError as e:
    print(f"Error sorting incompatible types: {e}")
# Out:
# Error sorting incompatible types: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# ### len(list)

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
student_counts = [350, 420, 380, 500, 450]
empty_list = []

# %%
# 1. Get the number of courses offered
num_courses = len(course_list)
print(f"Number of courses: {num_courses}")
# Out:
# Number of courses: 3

# %%
# 2. Get the number of student count entries
num_counts = len(student_counts)
print(f"Number of student count entries: {num_counts}")
# Out:
# Number of student count entries: 5

# %%
# 3. Get the length of an empty list
empty_len = len(empty_list)
print(f"Length of empty list: {empty_len}")
# Out:
# Length of empty list: 0

# %%
# 4. Use len() in a loop condition
tasks = ["Task1", "Task2"]
while len(tasks) > 0:
    task = tasks.pop(0)
    print(f"Processing task: {task}, Remaining: {len(tasks)}")
# Out:
# Processing task: Task1, Remaining: 1
# Processing task: Task2, Remaining: 0

# %%
# 5. Check if list is not empty before accessing index 0
if len(course_list) > 0:
    print(f"First course (list not empty): {course_list[0]}")
else:
    print("Course list is empty.")
# Out:
# First course (list not empty): Data Science

# %%
# 6. Length of a list containing other lists (counts nested lists as one item)
nested_list = [1, [2, 3], 4, [5, 6, 7]]
nested_len = len(nested_list)
print(f"Length of nested list: {nested_len}")
# Out:
# Length of nested list: 4

# %%
# 7. Length after appending an item
course_list.append("Cloud Computing") # List is now 4 items long
print(f"Length after append: {len(course_list)}")
# Out:
# Length after append: 4

# %%
# 8. Length after extending the list
more_courses = ["ML", "AI"]
course_list.extend(more_courses) # List is now 6 items long
print(f"Length after extend: {len(course_list)}")
# Out:
# Length after extend: 6

# %%
# 9. Length of a list created from a range
batch_ids = list(range(101, 106)) # [101, 102, 103, 104, 105]
num_batches = len(batch_ids)
print(f"Number of batch IDs: {num_batches}")
# Out:
# Number of batch IDs: 5

# %%
# 10. Length of list used in conditional message
if len(student_counts) >= 5:
    print(f"We have data for {len(student_counts)} course batches.")
# Out:
# We have data for 5 course batches.

# %%
# 10. Length of list used in conditional message
if len(student_counts) >= 6:
    print(f"We have data for {len(student_counts)} course batches.")
else:
    print(f"We have no enough data for {len(student_counts)} course batches")
# Out:
# We have no enough data for 5 course batches

# %% [markdown]
# ### list.clear()

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
tasks_to_clear = ["Task A", "Task B"]

# %%
# 1. Clear the course list
print(f"List before clear: {course_list}")
course_list.clear()
print(f"List after clear: {course_list}")
# Out:
# List before clear: ['Data Science', 'Data Engineering', 'Azure DevOps']
# List after clear: []

# %%
# 2. Clear the tasks list
print(f"Tasks before clear: {tasks_to_clear}")
tasks_to_clear.clear()
print(f"Tasks after clear: {tasks_to_clear}")
# Out:
# Tasks before clear: ['Task A', 'Task B']
# Tasks after clear: []

# %%
# 3. Clear a list that is already empty
empty_list = []
print(f"Empty list before clear: {empty_list}")
empty_list.clear()
print(f"Empty list after clear: {empty_list}")
# Out:
# Empty list before clear: []
# Empty list after clear: []

# %%
# 4. Use case: Resetting a list for reuse in a loop
batch_students = []
for batch in range(2):
    # Simulate loading students for a batch
    batch_students = [f"Student_{batch}_A", f"Student_{batch}_B"]
    print(f"Processing batch {batch+1}: {batch_students}")
    # Clear list for next batch (if logic required it)
    batch_students.clear()
    print(f"List after clear for batch {batch+1}: {batch_students}")
# Out:
# Processing batch 1: ['Student_0_A', 'Student_0_B']
# List after clear for batch 1: []
# Processing batch 2: ['Student_1_A', 'Student_1_B']
# List after clear for batch 2: []

# %%
# 5. Clearing a list of numbers
numbers = [1, 2, 3, 4, 5]
numbers.clear()
print(f"Numbers list after clear: {numbers}")
# Out:
# Numbers list after clear: []

# %%
# 6. Clearing a list of tuples
coordinates = [(0, 0), (1, 1)]
coordinates.clear()
print(f"Coordinates list after clear: {coordinates}")
# Out:
# Coordinates list after clear: []

# %%
# 7. Clearing a list with mixed types
mixed_list = ["Text", 10, None, True]
mixed_list.clear()
print(f"Mixed list after clear: {mixed_list}")
# Out:
# Mixed list after clear: []

# %%
# 8. Clearing a list referred to by another variable (affects both)
original_list = [100, 200]
ref_list = original_list # Both variables point to the same list
ref_list.clear()
print(f"Original list after clearing ref: {original_list}")
# Out:
# Original list after clearing ref: []

# %%
# 9. Clearing a slice doesn't work; clear() applies to the whole list object
data = [1, 2, 3, 4, 5]
# data[1:3].clear() # This is NOT valid syntax
data.clear() # Clears the whole list 'data'
print(f"Data after clearing whole list: {data}")
# Out:
# Data after clearing whole list: []

# %%
# 10. Re-populating a cleared list
cleared_list = ["Old Data"]
cleared_list.clear()
cleared_list.append("New Data 1")
cleared_list.append("New Data 2")
print(f"Re-populated list: {cleared_list}")
# Out:
# Re-populated list: ['New Data 1', 'New Data 2']

# %% [markdown]
# ### membership testing (in, not in)
# ### True or False

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
tech_skills = ["Python", "SQL", "Git", "CI/CD"]

# %%
# 1. Check if "Data Science" is in the course list
is_ds_offered = "Data Science" in course_list
print(f"Is 'Data Science' offered? {is_ds_offered}")
# Out:
# Is 'Data Science' offered? True

# %%
# 2. Check if "Machine Learning" is in the course list
is_ml_offered = "Machine Learning" in course_list
print(f"Is 'Machine Learning' offered? {is_ml_offered}")
# Out:
# Is 'Machine Learning' offered? False

# %%
# 3. Check if "Python" is NOT in the course list
is_python_not_in_courses = "Python" not in course_list
print(f"Is 'Python' not in courses? {is_python_not_in_courses}")
# Out:
# Is 'Python' not in courses? True

# %%
# 4. Check if "Python" IS in the tech skills list
is_python_in_skills = "Python" in tech_skills
print(f"Is 'Python' in tech skills? {is_python_in_skills}")
# Out:
# Is 'Python' in tech skills? True

# %%
# 5. Using 'in' in an if statement
course_needed = "SQL"
if course_needed in tech_skills:
    print(f"'{course_needed}' is a required skill.")
else:
    print(f"'{course_needed}' is not listed as a required skill.")
# Out:
# 'SQL' is a required skill.

# %%
# 6. Check for a number in a list of student counts
student_counts = [350, 420, 380]
is_420_present = 420 in student_counts
print(f"Is count 420 present? {is_420_present}")
# Out:
# Is count 420 present? True

# %%
# 7. Check for None in a list
optional_features = ["Feature A", None]
is_none_present = None in optional_features
print(f"Is None present in features? {is_none_present}")
# Out:
# Is None present in features? True

# %%
# 8. Check for a tuple in a list of tuples
coordinates = [(0, 0), (1, 1)]
point_to_check = (1, 1)
is_point_present = point_to_check in coordinates
print(f"Is point {point_to_check} present? {is_point_present}")
# Out:
# Is point (1, 1) present? True

# %%
# 9. Check for a list within a list (checks for the exact list object/value)
nested_list = [1, [2, 3], 4]
sub_list_check = [2, 3]
is_sublist_present = sub_list_check in nested_list
print(f"Is sub-list [2, 3] present? {is_sublist_present}")
# Out:
# Is sub-list [2, 3] present? True

# %%
# 10. Using 'not in' to add if missing
new_skill = "Docker"
if new_skill not in tech_skills:
    tech_skills.append(new_skill)
print(f"Tech skills after checking for '{new_skill}': {tech_skills}")
# Out:
# Tech skills after checking for 'Docker': ['Python', 'SQL', 'Git', 'CI/CD', 'Docker']
