# %% [markdown]
# ## range

# %% [markdown]
# ### Creation and Iteration

# %%
# 1. Simple range (0 up to, but not including, 5)
print("Looping with range(5):")
for i in range(5):
    print(f"   - Iteration {i}")
# Out:
# Looping with range(5):
#    - Iteration 0
#    - Iteration 1
#    - Iteration 2
#    - Iteration 3
#    - Iteration 4

# %%
# 2. Range with start and stop (batch IDs 101 to 105)
batch_ids = range(101, 106)
print(f"\nProcessing Batch IDs: {batch_ids}")
for batch_id in batch_ids:
    print(f" - Processing Batch {batch_id}")
# Out:
# Processing Batch IDs: range(101, 106)
#  - Processing Batch 101
#  - Processing Batch 102
#  - Processing Batch 103
#  - Processing Batch 104
#  - Processing Batch 105

# %%
# 3. Range with start, stop, and step (even numbers 0 to 8)
even_numbers = range(0, 10, 2)
print(f"\nEven numbers range: {even_numbers}")
for num in even_numbers:
    print(f" - Even number: {num}")
# Out:
# Even numbers range: range(0, 10, 2)
#  - Even number: 0
#  - Even number: 2
#  - Even number: 4
#  - Even number: 6
#  - Even number: 8

# %%
# 4. Range with negative step (countdown from 5 down to 1)
countdown = range(5, 0, -1)
print("\nCountdown:")
for i in countdown:
    print(f"- T-minus {i}")
# Out:
# Countdown:
# - T-minus 5
# - T-minus 4
# - T-minus 3
# - T-minus 2
# - T-minus 1

# %%
# 5. Creating a range object directly
module_range = range(1, 6) # Represents modules 1 to 5
print(f"\nModule range object: {module_range}")
# Out:
# Module range object: range(1, 6)

# %%
# 6. Iterating through indices of a list
course_list = ["DS", "DE", "ADO"]
print("\nAccessing courses by index:")
for i in range(len(course_list)):
    print(f" - Index {i}: {course_list[i]}")
# Out:
# Accessing courses by index:
#  - Index 0: DS
#  - Index 1: DE
#  - Index 2: ADO

# %%
# 7. Range where start equals stop (empty sequence)
empty_range = range(5, 5)
print("\nIterating over empty range:")
for i in empty_range:
    print(f"   - This won't print: {i}") # No output from loop
print(f"   (Empty range object: {empty_range})")
# Out:
# Iterating over empty range:
#    (Empty range object: range(5, 5))

# %%
# 8. Range where step doesn't allow reaching stop (e.g., positive step when start > stop)
invalid_step_range = range(10, 0, 1) # Start=10, Stop=0, Step=1 -> Empty
print("\nIterating over invalid step range:")
for i in invalid_step_range:
    print(f"- This won't print: {i}") # No output
print(f"(Invalid step range object: {invalid_step_range})")
# Out:
# Iterating over invalid step range:
# (Invalid step range object: range(10, 0))

# %%
# 9. Converting range to list to see all numbers
batch_list = list(range(101, 106))
print(f"\n Batch IDs as a list: {batch_list}")
# Out:
#  Batch IDs as a list: [101, 102, 103, 104, 105]

# %%
# 10. Converting range to tuple
even_tuple = tuple(range(0, 10, 2))
print(f"Even numbers as tuple: {even_tuple}")
# Out:
# Even numbers as tuple: (0, 2, 4, 6, 8)

# %% [markdown]
# ### len(), membership (in, not in), Indexing, Slicing

# %%
batch_ids = range(101, 106) # 101, 102, 103, 104, 105
numbers = range(0, 20, 3) # 0, 3, 6, 9, 12, 15, 18

# %%
# 1. Get the number of items in batch_ids range
num_batches = len(batch_ids)
print(f"Number of batch IDs: {num_batches}")
# Out:
# Number of batch IDs: 5

# %%
# 2. Get the number of items in numbers range
count_numbers = len(numbers)
print(f"Count of numbers in range(0, 20, 3): {count_numbers}")
# Out:
# Count of numbers in range(0, 20, 3): 7

# %%
# 3. Check if batch ID 103 is in the range
is_103_present = 103 in batch_ids
print(f"Is batch ID 103 present? {is_103_present}")
# Out:
# Is batch ID 103 present? True

# %%
# 4. Check if batch ID 106 is in the range
is_106_present = 106 in batch_ids
print(f"Is batch ID 106 present? {is_106_present}")
# Out:
# Is batch ID 106 present? False

# %%
# 5. Check if 10 is NOT in the 'numbers' range
is_10_not_present = 10 not in numbers
print(f"Is 10 not in numbers range? {is_10_not_present}")
# Out:
# Is 10 not in numbers range? True

# %%
# 6. Check if 12 IS in the 'numbers' range
is_12_present = 12 in numbers
print(f"Is 12 in numbers range? {is_12_present}")
# Out:
# Is 12 in numbers range? True

# %%
# 7. Get the first element (index 0) of batch_ids
first_batch_id = batch_ids[0]
print(f"First batch ID (index 0): {first_batch_id}")
# Out:
# First batch ID (index 0): 101

# %%
# 8. Get the third element (index 2) of batch_ids
third_batch_id = batch_ids[2]
print(f"Third batch ID (index 2): {third_batch_id}")
# Out:
# Third batch ID (index 2): 103

# %%
# 9. Get a slice of the batch_ids range (returns another range object)
batch_slice = batch_ids[1:4] # Represents indices 1, 2, 3 -> numbers 102, 103, 104
print(f"Slice of batch IDs [1:4]: {batch_slice}") # Output: range(102, 105)
print(f"Slice as list: {list(batch_slice)}")
# Out:
# Slice of batch IDs [1:4]: range(102, 105)
# Slice as list: [102, 103, 104]

# %%
# 10. Get the last element using negative index
last_batch_id = batch_ids[-1]
print(f"Last batch ID (index -1): {last_batch_id}")
# Out:
# Last batch ID (index -1): 105
