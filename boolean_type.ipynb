# %% [markdown]
# ## Boolean type(bool)

# %%
# ex:
is_data_science_active = True
is_azure_devops_course_full = False
is_python_essential = True

# %% [markdown]
# ### - Literals and Comparisons

# %%
total_students = 1500
capacity = 1500
average_rating = 4.8
min_rating = 4.5

# %%
# 1. Boolean literal True
is_data_science_active = True
print(f"DS Active Status: {is_data_science_active}")
# Out:
# DS Active Status: True

# %%
# 2. Boolean literal False
is_azure_devops_course_full = False
print(f"ADO Full Status: {is_azure_devops_course_full}")
# Out:
# ADO Full Status: False

# %%
# 3. Equality check (==)
at_capacity = (total_students == capacity)
print(f"Is course at capacity? {at_capacity}")
# Out:
# Is course at capacity? True

# %%
# 4. Inequality check (!=)
has_vacancies = (total_students != capacity)
print(f"Are there vacancies? {has_vacancies}")
# Out:
# Are there vacancies? False

# %%
# 5. Greater than check (>)
rating_is_good = (average_rating > min_rating)
print(f"Is average rating good? {rating_is_good}")
# Out:
# Is average rating good? True

# %%
# 6. Less than check (<)
needs_improvement = (average_rating < 4.0)
print(f"Does rating need improvement? {needs_improvement}")
# Out:
# Does rating need improvement? False

# %%
# 7. Greater than or equal check (>=)
meets_min_rating = (average_rating >= min_rating)
print(f"Does rating meet minimum? {meets_min_rating}")
# Out:
# Does rating meet minimum? True

# %%
# 8. Less than or equal check (<=)
enrollment_below_target = (total_students <= 2000)
print(f"Is enrollment <= 2000? {enrollment_below_target}")
# Out:
# Is enrollment <= 2000? True

# %%
# 9. Comparing strings
institute = "Edukron"
is_edukron = (institute == "Edukron")
print(f"Is institute name 'Edukron'? {is_edukron}")
# Out:
# Is institute name 'Edukron'? True

# %%
# 10. Comparing booleans themselves
are_flags_equal = (is_data_science_active == is_python_essential) # True == True
print(f"Are DS active and Python essential flags equal? {are_flags_equal}")
# Out:
# Are DS active and Python essential flags equal? True

# %% [markdown]
# ### boolean operators (and, or, not)

# %%
is_data_science_active = True
is_azure_devops_course_full = False
average_rating = 4.8
min_rating = 4.5
has_prerequisites = True

# %%
# 1. AND: Check if DS is active AND rating is good
can_recommend_ds = is_data_science_active and (average_rating > min_rating)
print(f"Can recommend Data Science course? {can_recommend_ds}")
# Out:
# Can recommend Data Science course? True

# %%
# 2. AND: Check if ADO is full AND rating is good (Short-circuits)
should_waitlist_ado = is_azure_devops_course_full and (average_rating > min_rating)
print(f"Should waitlist for Azure DevOps? {should_waitlist_ado}")
# Out:
# Should waitlist for Azure DevOps? False

# %%
# 3. OR: Check if DS is active OR ADO is full
show_course_status = is_data_science_active or is_azure_devops_course_full
print(f"Show status (DS active or ADO full)? {show_course_status}")
# Out:
# Show status (DS active or ADO full)? True

# %%
# 4. OR: Check if rating is low OR ADO is full (Short-circuits)
needs_attention = (average_rating < 4.0) or is_azure_devops_course_full
print(f"Does Edukron need attention (low rating or full ADO)? {needs_attention}")
# Out:
# Does Edukron need attention (low rating or full ADO)? False

# %%
# 5. NOT: Check if ADO course is NOT full
can_enroll_ado = not is_azure_devops_course_full
print(f"Can enroll in Azure DevOps? {can_enroll_ado}")
# Out:
# Can enroll in Azure DevOps? True

# %%
# 6. NOT: Check if DS course is NOT active
is_ds_inactive = not is_data_science_active
print(f"Is Data Science course inactive? {is_ds_inactive}")
# Out:
# Is Data Science course inactive? False

# %%
# 7. Combining operators: Active course with good rating and prerequisites met
eligible_to_start = is_data_science_active and (average_rating >= min_rating) and has_prerequisites
print(f"Eligible to start Data Science? {eligible_to_start}")
# Out:
# Eligible to start Data Science? True

# %%
# 8. Combining operators: Not full OR has prerequisites
can_consider = (not is_azure_devops_course_full) or has_prerequisites
print(f"Can consider ADO (not full or has prereqs)? {can_consider}")
# Out:
# Can consider ADO (not full or has prereqs)? True

# %%
# 9. Complex combination with parentheses
# Active AND (Good rating OR Not Full)
complex_check = is_data_science_active and ((average_rating > 4.7) or (not is_azure_devops_course_full))
print(f"Complex Check Result: {complex_check}")
# Out:
# Complex Check Result: True

# %%
# 10. Using boolean variable directly with 'not'
is_python_essential = True
is_optional = not is_python_essential
print(f"Is Python optional? {is_optional}")
# Out:
# Is Python optional? False

# %% [markdown]
# ### bool() constructor and Truth Value testing

# %%
total_students = 1500
average_rating = 4.8
course_list = ["Data Science", "Data Engineering"]
empty_list = []
student_name = "Alice"
no_name = ""
zero_count = 0

# %%
# 1. bool() of a non-zero integer
bool_students = bool(total_students)
print(f"bool({total_students}): {bool_students}")
# Out:
# bool(1500): True

# %%
# 2. bool() of zero
bool_zero = bool(zero_count)
print(f"bool({zero_count}): {bool_zero}")
# Out:
# bool(0): False

# %%
# 3. bool() of a non-empty list
bool_courses = bool(course_list)
print(f"bool(course_list): {bool_courses}")
# Out:
# bool(course_list): True

# %%
# 4. bool() of an empty list
bool_empty = bool(empty_list)
print(f"bool(empty_list): {bool_empty}")
# Out:
# bool(empty_list): False

# %%
# 5. bool() of a non-empty string
bool_name = bool(student_name)
print(f"bool('{student_name}'): {bool_name}")
# Out:
# bool('Alice'): True

# %%
# 6. bool() of an empty string
bool_no_name = bool(no_name)
print(f"bool(''): {bool_no_name}")
# Out:
# bool(''): False

# %%
# 7. bool() of None
bool_none = bool(None)
print(f"bool(None): {bool_none}")
# Out:
# bool(None): False

# %%
# 8. Truth value testing in 'if' (non-empty list is True)
if course_list:
    print("Course list is not empty (truthy).")
else:
    print("Course list is empty (falsy).")
# Out:
# Course list is not empty (truthy).

# %%
# 9. Truth value testing in 'if' (empty list is False)
if empty_list:
    print("This won't print (empty list is falsy).")
else:
    print("Empty list evaluated as False.")
# Out:
# Empty list evaluated as False.

# %%
# 10. Truth value testing with 'or' default pattern
# Get student name, or use "Guest" if name is empty (falsy)
current_user = no_name or "Guest"
print(f"Current user (empty name): {current_user}")
current_user = student_name or "Guest"
print(f"Current user (non-empty name): {current_user}")
# Out:
# Current user (empty name): Guest
# Current user (non-empty name): Alice
