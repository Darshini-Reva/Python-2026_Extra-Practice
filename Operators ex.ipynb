# %% [markdown]
# ## Addition

# %%
ds_modules = 15
de_modules = 18
total_modules = ds_modules + de_modules
print ( "Total modules in DS & DE :", total_modules)
# Out:
# Total modules in DS & DE : 33

# %%
# 1. Adding new student to the total
new_students_batch1 = 120
total_students = 1500
total_students =  total_students + new_students_batch1
print (f"1. Total students after batch 1 is: {total_students}")
# Out:
# 1. Total students after batch 1 is: 1620

# %%
# 2. Calculating total modules in two courses
batch_size_1 = 50
batch_size_2 = 45
combined_batch_size = batch_size_1 + batch_size_2
print (f"2. Combined batch size is: {combined_batch_size}")
# Out:
# 2. Combined batch size is: 95

# %%
batch_size_1 = 50
batch_size_2 = 45
combined_batch_size = batch_size_1 + batch_size_2
print (combined_batch_size)
# Out:
# 95

# %%
# 3. Summing batch sizes
batch_size_1 = 50
batch_size_2 = 45
combined_batch_size = batch_size_1 + batch_size_2
print (f"3. combined sizes of two batches: {combined_batch_size}")
# Out:
# 3. combined sizes of two batches: 95

# %%
# 4. Adding zero doesn't change the value
initial_count = 100
final_count = initial_count + 0
print(f"4. Count after adding zero: {final_count}")
# Out:
# 4. Count after adding zero: 100

# %%
# 5. Adding a negative number (subtraction)
active_students = 1620
dropouts = -20
active_students = active_students + dropouts
print(f"5. Actives students after accounting for dropouts: {active_students}")
# Out:
# 5. Actives students after accounting for dropouts: 1600

# %%
# 6. Incrementing a counter
completed_projects = 5
completed_projects = completed_projects + 1
print(f"6. Completed projects incremented: {completed_projects}")
# Out:
# 6. Completed projects incremented: 6

# %%
# 7. Summing course durations (in weeks)
duration1 = 8
duration2 = 12
total_duration = duration1 + duration2
print(f"7. Total duration in weeks : {total_duration}")
# Out:
# 7. Total duration in weeks : 20

# %%
# 8. Adding instructor counts
ds_instructors = 3
de_instructors = 4
total_instructors = ds_instructors + de_instructors
print(f"8. Total instructors: {total_instructors}")
# Out:
# 8. Total instructors: 7

# %%
# 9. Calculating total assignments
assignments_part1 = 25
assignments_part2 = 30
total_assignments = assignments_part1 + assignments_part2
print(f"9. Total assignments: {total_assignments}")
# Out:
# 9. Total assignments: 55

# %%
# 10. Combining positive and negative changes
student_change = 50 + (-10) + 30
print(f"10. Net student change: {student_change}")
# Out:
# 10. Net student change: 70

# %%
student_change = 50 + (-10) + 30
print(student_change)
# Out:
# 70

# %% [markdown]
# ## Subtraction

# %%
# 1. Calculating remaining seats
batch_capacity = 60
enrolled = 55
remaining_seats = batch_capacity - enrolled
print(f"1. Remaining seats: {remaining_seats}")
# Out:
# 1. Remaining seats: 5

# %%
# 2. Calculating student dropouts
initial_students = 1500
final_students = 1485
dropouts = initial_students - final_students
print(f"2. Number of dropouts: {dropouts}")
# Out:
# 2. Number of dropouts: 15

# %%
# 3. Finding the difference in module counts
ds_modules = 15
de_modules = 18
module_difference = de_modules - ds_modules
print(f"3. Difference in modules: {module_difference}")
# Out:
# 3. Difference in modules: 3

# %%
# 4. Subtracting zero
revenue = 50000
revenue_after_discount = revenue - 0
print(f"4. Revenue after zero discount: {revenue_after_discount}")
# Out:
# 4. Revenue after zero discount: 50000

# %%
# 5. Resulting in a negative number
costs = 60000
profit = revenue - costs
print(f"5. Profit (can be negative): {profit}")
# Out:
# 5. Profit (can be negative): -10000

# %%
print(profit)
# Out:
# -10000

# %%
# 6. Decrementing a counter
live_sessions_left = 10
live_sessions_left = live_sessions_left - 1
print(f"6. Live sessions left after one: {live_sessions_left}")
# Out:
# 6. Live sessions left after one: 9

# %%
# 7. Calculating years since launch
current_year = 2024
launch_year = 2020
years_active = current_year - launch_year
print(f"7. Edukron years active: {years_active}")
# Out:
# 7. Edukron years active: 4

# %%
# 8. Finding difference between target and actual enrollment
target_enrollment = 2000
total_students = 1500
shortfall = target_enrollment - total_students
print(f"8. Enrollment shortfall: {shortfall}")
# Out:
# 8. Enrollment shortfall: 500

# %%
# 9. Subtracting a negative number (addition)
initial_score = 80
score_penalty = -10 
final_score = initial_score - score_penalty
print(f"9. Score after reversing penalty: {final_score}")
# Out:
# 9. Score after reversing penalty: 90

# %%
# 10. Days remaining in a course
total_days = 90
days_passed = 30
days_remaining = total_days - days_passed
print(f"10. Days remaining: {days_remaining}")
# Out:
# 10. Days remaining: 60

# %% [markdown]
# ## Multiplication

# %%
# 1. Calculating total revenue
total_students = 1500
course_fee = 500
total_revenue = total_students * course_fee
print(f"1. Total potential revenue: ${total_revenue}")
# Out:
# 1. Total potential revenue: $750000

# %%
# 2. Calculating total hours for a course
modules = 15
hours_per_module = 4
total_hours = modules * hours_per_module
print(f"2. Total course hours: {total_hours}")
# Out:
# 2. Total course hours: 60

# %%
# 3. Scaling up projected growth
monthly_growth = 50 
months = 12
annual_growth_projection = monthly_growth * months
print(f"3. Projected annual growth: {annual_growth_projection}")
# Out:
# 3. Projected annual growth: 600

# %%
# 4. Multiplying by zero
zero_enrollment_batches = 0
students_per_batch = 50
total_from_zero_batches = zero_enrollment_batches * students_per_batch
print(f"4. Students from zero batches: {total_from_zero_batches}")
# Out:
# 4. Students from zero batches: 0

# %%
# 5. Multiplying by one
active_courses = 3
multiplier = 1
result = active_courses * multiplier
print(f"5. Multiplying by one: {result}")
# Out:
# 5. Multiplying by one: 3

# %%
# 6. Calculating cost based on usage
api_calls = 10000
cost_per_call = 2 # cents
total_api_cost = api_calls * cost_per_call
print(f"6. Total API cost (cents): {total_api_cost}")
# Out:
# 6. Total API cost (cents): 20000

# %%
# 7. Multiplying by a negative number
profit_per_student = 100
refunds = -5 # Representing 5 refunds
impact_on_profit = refunds * profit_per_student
print(f"7. Profit impact from refunds: ${impact_on_profit}")
# Out:
# 7. Profit impact from refunds: $-500

# %%
# 8. Calculating total storage needed
students = 1500
storage_per_student_gb = 2
total_storage_gb = students * storage_per_student_gb
print(f"8. Total storage needed (GB): {total_storage_gb}")
# Out:
# 8. Total storage needed (GB): 3000

# %%
# 9. Area calculation (simple example)
width = 10
height = 5
area = width * height
print(f"9. Simple area: {area}") # Output: 50
# Out:
# 9. Simple area: 50

# %%
# 10. Total quizzes across modules
modules = 15
quizzes_per_module = 3
total_quizzes = modules * quizzes_per_module
print(f"10. Total quizzes: {total_quizzes}")
# Out:
# 10. Total quizzes: 45

# %% [markdown]
# ## Division
