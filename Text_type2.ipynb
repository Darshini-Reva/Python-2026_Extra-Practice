# %% [markdown]
# ## text type (str)

# %% [markdown]
# ### str.replace(old,new[,count])

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python and SQL"

# %%
# 1. Replacing 'Data Engineering' with 'Data Science'
new_slogan = course_slogan.replace("Data Engineering", "Data Science")
print(f"New slogan: '{new_slogan}'")
# Out:
# New slogan: 'Learn Data Science with Real-Time Projects'

# %%
# 2. Replacing spaces with underscores
slug = course_slogan.replace(" ", "_").lower() # Chain with lower()
print(f"Slugified slogan: '{slug}'")
# Out:
# Slugified slogan: 'learn_data_engineering_with_real-time_projects'

# %%
# 2. Replacing spaces with underscores
slug = course_slogan.replace(" ", "_")
print(f"Slugified slogan: '{slug}'")
# Out:
# Slugified slogan: 'Learn_Data_Engineering_with_Real-Time_Projects'

# %%
# 3. Replacing 'and' with '&' in tech_stack
ampersand_stack = tech_stack.replace("and", "&")
print(f"Tech stack with ampersand: '{ampersand_stack}'")
# Out:
# Tech stack with ampersand: 'Azure DevOps & Python & SQL'

# %%
# 4. Replacing only the first occurrence of 'and'
first_ampersand = tech_stack.replace("and", "&", 1)
print(f"Replacing first 'and' only: '{first_ampersand}'")
# Out:
# Replacing first 'and' only: 'Azure DevOps & Python and SQL'

# %%
# 5. Removing all spaces
no_spaces = course_slogan.replace(" ", "")
print(f"Slogan without spaces: '{no_spaces}'")
# Out:
# Slogan without spaces: 'LearnDataEngineeringwithReal-TimeProjects'

# %%
# 6. Replacing a character that doesn't exist (no change)
result = course_slogan.replace("Java", "Python")
print(f"Replacing non-existent substring: '{result}'")
# Out:
# Replacing non-existent substring: 'Learn Data Engineering with Real-Time Projects'

# %%
# 7. Replacing with an empty string (effectively deleting)
deleted_realtime = course_slogan.replace("Real-Time ", "")
print(f"Deleting 'Real-Time ': '{deleted_realtime}'")
# Out:
# Deleting 'Real-Time ': 'Learn Data Engineering with Projects'

# %%
# 8. Case-sensitive replacement
text = "Python python pYthon"
result = text.replace("python", "PYTHON") # Only replaces lowercase 'python'
print(f"Case-sensitive replace: '{result}'")
# Out:
# Case-sensitive replace: 'Python PYTHON pYthon'

# %%
# 9. Replacing multiple characters (by chaining)
filename = "project report final.docx"
clean_filename = filename.replace(" ", "_").replace(".docx", ".pdf")
print(f"Chained replace for filename: '{clean_filename}'")
# Out:
# Chained replace for filename: 'project_report_final.pdf'

# %%
# 10. Replacing using count=0 (no change)
result = tech_stack.replace("and", "&", 0)
print(f"Replacing with count=0: '{result}'")
# Out:
# Replacing with count=0: 'Azure DevOps and Python and SQL'

# %% [markdown]
# ### str.split(sep=None, maxsplit=-1)

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps,Python,SQL,Git"
institute = "Edukron"

# %%
# 1. Splitting slogan by whitespace (default)
words = course_slogan.split()
print(f"Slogan words: {words}")
# Out:
# Slogan words: ['Learn', 'Data', 'Engineering', 'with', 'Real-Time', 'Projects']

# %%
# 2. Splitting tech stack by comma
skills = tech_stack.split(',')
print(f"Tech skills: {skills}")
# Out:
# Tech skills: ['Azure DevOps', 'Python', 'SQL', 'Git']

# %%
# 3. Splitting institute name by character 'k'
parts = institute.split('k')
print(f"Splitting '{institute}' by 'k': {parts}")
# Out:
# Splitting 'Edukron' by 'k': ['Edu', 'ron']

# %%
# 4. Splitting slogan with maxsplit=2
split_limit = course_slogan.split(maxsplit=2)
print(f"Splitting slogan (maxsplit=2): {split_limit}")
# Out:
# Splitting slogan (maxsplit=2): ['Learn', 'Data', 'Engineering with Real-Time Projects']

# %%
# 5. Splitting tech stack by comma with maxsplit=1
split_tech_limit = tech_stack.split(',', maxsplit=1)
print(f"Splitting tech stack (maxsplit=1): {split_tech_limit}")
# Out:
# Splitting tech stack (maxsplit=1): ['Azure DevOps', 'Python,SQL,Git']

# %%
# 6. Splitting a string with multiple spaces (default handles it)
multi_space = "Azure   DevOps  Python"
words = multi_space.split()
print(f"Splitting multi-space string: {words}")
# Out:
# Splitting multi-space string: ['Azure', 'DevOps', 'Python']

# %%
# 7. Splitting by a separator that is not present
result = course_slogan.split("---")
print(f"Splitting by non-existent separator: {result}")
# Out:
# Splitting by non-existent separator: ['Learn Data Engineering with Real-Time Projects']

# %%
# 8. Splitting an empty string
result = "".split()
print(f"Splitting empty string (default sep): {result}") # Output: []
result_sep = "".split(',')
print(f"Splitting empty string (with sep): {result_sep}")
# Out:
# Splitting empty string (default sep): []
# Splitting empty string (with sep): ['']

# %%
# 9. Splitting a string that starts/ends with separator (using sep)
path = "/data/science/"
parts = path.split('/')
print(f"Splitting path '{path}' by '/': {parts}")
# Out:
# Splitting path '/data/science/' by '/': ['', 'data', 'science', '']

# %%
# 10. Splitting line breaks
multi_line = "Edukron\nData Science\nAzure"
lines = multi_line.split('\n')
print(f"Splitting by newline: {lines}")
# Out:
# Splitting by newline: ['Edukron', 'Data Science', 'Azure']

# %% [markdown]
# ### str.join(iterable)

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
tech_skills = ("Python", "SQL", "Git", "CI/CD")
words = ['Learn', 'Data', 'Engineering']

# %%
# 1. Joining course list with a comma and space
joined_courses = ", ".join(course_list)
print(f"Joined courses: '{joined_courses}'")
# Out:
# Joined courses: 'Data Science, Data Engineering, Azure DevOps'

# %%
# 2. Joining tech skills with a hyphen
joined_skills = "-".join(tech_skills)
print(f"Joined skills: '{joined_skills}'")
# Out:
# Joined skills: 'Python-SQL-Git-CI/CD'

# %%
# 3. Joining words back into a sentence with spaces
sentence = " ".join(words)
print(f"Rejoined sentence: '{sentence}'")
# Out:
# Rejoined sentence: 'Learn Data Engineering'

# %%
# 4. Joining with an empty string (no separator)
institute = "Edukron"
chars = list(institute)
print(chars) # ['E', 'd', 'u', 'k', 'r', 'o', 'n']
joined_chars = "".join(chars)
print(f"Joining chars with empty string: '{joined_chars}'")
# Out:
# ['E', 'd', 'u', 'k', 'r', 'o', 'n']
# Joining chars with empty string: 'Edukron'

# %%
# 5. Joining using a multi-character separator
separator = " | "
joined_fancy = separator.join(course_list)
print(f"Joining with ' | ': '{joined_fancy}'")
# Out:
# Joining with ' | ': 'Data Science | Data Engineering | Azure DevOps'

# %%
# 6. Joining an iterable with only one element
single_item_list = ["Azure DevOps"]
result = ", ".join(single_item_list)
print(f"Joining single item list: '{result}'")
# Out:
# Joining single item list: 'Azure DevOps'

# %%
# 7. Joining an empty iterable
empty_list = []
result = ", ".join(empty_list)
print(f"Joining empty list: '{result}'")
# Out:
# Joining empty list: ''

# %%
# 8. Joining elements that are not just words
items = ["Course", "Batch101", "Module5"]
identifier = "_".join(items)
print(f"Joining items with underscore: '{identifier}'")
# Out:
# Joining items with underscore: 'Course_Batch101_Module5'

# %%
# 9. Joining using newline as separator
report_lines = ["Edukron Status Report", "Students: 1500", "Rating: 4.8"]
report = "\n".join(report_lines)
print(f"Joining with newline:\n{report}")
# Out:
# Joining with newline:
# Edukron Status Report
# Students: 1500
# Rating: 4.8

# %%
# 10. Joining requires all elements to be strings (TypeError otherwise)
mixed_list = ["Data Science", 101]
try:
    error_join = ", ".join(mixed_list)
except TypeError as e:
    print(f"Error joining list with non-string: {e}")
# Out:
# Error joining list with non-string: sequence item 1: expected str instance, int found

# %% [markdown]
# ### str.startswith(prefix[,start[,end]]) & str.endswith(suffix[,start[,end]])

# %%
institute = "Edukron"
course_slogan = "Learn Data Engineering with Real-Time Projects"
filename = "edukron_report.pdf"

# %%
# 1. Check if institute starts with "Edu"
starts_edu = institute.startswith("Edu")
print(f"Does '{institute}' start with 'Edu'? {starts_edu}")
# Out:
# Does 'Edukron' start with 'Edu'? True

# %%
# 2. Check if institute starts with "Data"
starts_data = institute.startswith("Data")
print(f"Does '{institute}' start with 'Data'? {starts_data}")
# Out:
# Does 'Edukron' start with 'Data'? False

# %%
# 3. Check if slogan ends with "Projects"
ends_projects = course_slogan.endswith("Projects")
print(f"Does slogan end with 'Projects'? {ends_projects}")
# Out:
# Does slogan end with 'Projects'? True

# %%
# 4. Check if filename ends with ".pdf"
ends_pdf = filename.endswith(".pdf")
print(f"Does '{filename}' end with '.pdf'? {ends_pdf}")
# Out:
# Does 'edukron_report.pdf' end with '.pdf'? True

# %%
# 5. Check if filename ends with ".csv" or ".pdf"
ends_data_format = filename.endswith((".csv", ".pdf"))
print(f"Does '{filename}' end with '.csv' or '.pdf'? {ends_data_format}")
# Out:
# Does 'edukron_report.pdf' end with '.csv' or '.pdf'? True

# %%
# 6. Check if slogan starts with "Learn" or "Explore"
starts_learn_explore = course_slogan.startswith(("Learn", "Explore"))
print(f"Does slogan start with 'Learn' or 'Explore'? {starts_learn_explore}")
# Out:
# Does slogan start with 'Learn' or 'Explore'? True

# %%
# 7. Check a slice: Does "Engineering" start at index 11 in slogan?
slice_check_start = course_slogan.startswith("Engineering", 11)
print(f"Does slogan start with 'Engineering' at index 11? {slice_check_start}")
# Out:
# Does slogan start with 'Engineering' at index 11? True

# %%
# 8. Check a slice: Does "Real-Time" end at index 36 in slogan?
# Slice [start:end] includes start, excludes end. So we check up to index 36.
slice_check_end = course_slogan.endswith("Real-Time", 0, 36)
print(f"Does slogan[0:36] end with 'Real-Time'? {slice_check_end}")
# Out:
# Does slogan[0:36] end with 'Real-Time'? False

# %%
# 9. Case-sensitive check (starts with 'learn')
starts_learn_lower = course_slogan.startswith("learn")
print(f"Does slogan start with 'learn' (lowercase)? {starts_learn_lower}")
# Out:
# Does slogan start with 'learn' (lowercase)? False

# %%
# 10. Check endswith on an empty string
ends_anything = "".endswith("anything")
print(f"Does '' end with 'anything'? {ends_anything}")
# Out:
# Does '' end with 'anything'? False

# %% [markdown]
# ### str.find(sub[,start[,end]]) and str.index(sub[,start[,end]])

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python"

# %%
# 1. Find the index of "Data" in the slogan
data_pos = course_slogan.find("Data")
print(f"Index of 'Data' using find(): {data_pos}")
# Out:
# Index of 'Data' using find(): 6

# %%
# 2. Find the index of "Python" in tech_stack
python_pos = tech_stack.find("Python")
print(f"Index of 'Python' using find(): {python_pos}")
# Out:
# Index of 'Python' using find(): 17

# %%
# 3. Find a substring that doesn't exist
java_pos = course_slogan.find("Java")
print(f"Index of 'Java' using find(): {java_pos}")
# Out:
# Index of 'Java' using find(): -1

# %%
# 4. Use index() to find "Azure" (will succeed)
azure_pos = tech_stack.index("Azure")
print(f"Index of 'Azure' using index(): {azure_pos}")
# Out:
# Index of 'Azure' using index(): 0

# %%
# 5. Use index() to find "Java" (will fail)
try:
    java_pos_index = course_slogan.index("Java")
except ValueError as e:
    print(f"Error using index() to find 'Java': {e}")
# Out:
# Error using index() to find 'Java': substring not found

# %%
# 6. Find "Engineering" starting search from index 10
eng_pos_slice = course_slogan.find("Engineering", 10)
print(f"Index of 'Engineering' starting at 10: {eng_pos_slice}")
# Out:
# Index of 'Engineering' starting at 10: 11

# %%
# 7. Find "e" starting search from index 2
e_pos_slice = course_slogan.find("e", 2) # First 'e' is at index 1, next is at 12
print(f"Index of 'e' starting at 2: {e_pos_slice}")
# Out:
# Index of 'e' starting at 2: 16

# %%
# 8. Find the last occurrence (using rfind() or rindex())
last_e_pos = course_slogan.rfind("e") # rfind searches from the right
print(f"Index of last 'e' using rfind(): {last_e_pos}")
# Out:
# Index of last 'e' using rfind(): 42

# %%
# 9. Find using an end index: find 'Data' before index 10
data_pos_end = course_slogan.find("Data", 0, 10)
print(f"Index of 'Data' before index 10: {data_pos_end}")
# Out:
# Index of 'Data' before index 10: 6

# %%
# 10. Find in an empty string
empty_find = "".find("a")
print(f"Find 'a' in empty string: {empty_find}")
# Out:
# Find 'a' in empty string: -1
